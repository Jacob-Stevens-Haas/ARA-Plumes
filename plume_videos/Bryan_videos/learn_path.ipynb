# %%
import sys
sys.path.append('/Users/Malachite/Documents/UW/ARA/ARA-Plumes/')
from models import PLUME

# %% [markdown]
# ## Testing background subtraction methods

# %%
# Instatiate PLUME tracker
video_path = "/Users/Malachite/Documents/UW/ARA/ARA-Plumes/plume_videos/Bryan_videos/Hsv-F0-3000.mp4"
tracker = PLUME(video_path=video_path)

# Declare where leak source 
plume_leak_source = (1182, 462)
tracker.orig_center = plume_leak_source

# Declare params for subtraction method - fixed subtraction
fixed_range = 5
img_range = [1,751]

# coeff_data = tracker.train(img_range=img_range, fixed_range=fixed_range)
# print(tracker.video_capture)
tracker.background_subtract(img_range=img_range, fixed_range=fixed_range, save=True)
# print(tracker.video_capture)
# Out:
# Creating background image...
# ret: True
# done.
# 100%|██████████| 750/750 [00:07<00:00, 103.78it/s]
